# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# #### Importing Libraries

# %%
import sys
sys.path.append('../')
import pandas as pd
from src.utils import check_missing_data
from src.descriptive_statistics import describe_numerical, summarize_categorical, summarize_time_series
from src.plots import display_summary_table, plot_bar_charts,plot_bar_chart, box_plots

# %% [markdown]
# #### Loading Data

# %%
df_data = pd.read_csv('../data/msgs_dataset.csv')

# %%
df_data.head()
# Out:
#                                  signature  channel_id channel_name  msg_id  \
# 0  msg_iteration.0.user.DoctorsET.post.864  1102021238    DoctorsET     864
# 1  msg_iteration.1.user.DoctorsET.post.863  1102021238    DoctorsET     863
# 2  msg_iteration.2.user.DoctorsET.post.862  1102021238    DoctorsET     862
# 3  msg_iteration.3.user.DoctorsET.post.861  1102021238    DoctorsET     861
# 4  msg_iteration.4.user.DoctorsET.post.860  1102021238    DoctorsET     860
#
#                                              message  \
# 0  https://youtu.be/5DBoEm-8kmA?si=LDLuEecNfULJVD...
# 1  ዶክተርስ ኢትዮጵያ በ አዲስ አቀራረብ በ ቴሌቪዥን ፕሮግራሙን ለመጀመር ከ...
# 2  ሞት በስኳር \n\nለልጆቻችን የምናሲዘው ምሳቃ ሳናቀው እድሚያቸውን ይቀን...
# 3  ከ HIV የተፈወሰ ሰው አጋጥሟችሁ ያቃል ? ፈውስ እና ህክምና ?\n\nሙ...
# 4  በቅርብ ጊዜ በሃገራችን ላይ እየተስተዋለ ያለ የተመሳሳይ ፆታ ( Homos...
#
#                                      cleaned_message  \
# 0  https://youtu.be/5DBoEm-8kmA?si=LDLuEecNfULJVD...
# 1  ዶክተርስ ኢትዮጵያ በ አዲስ አቀራረብ በ ቴሌቪዥን ፕሮግራሙን ለመጀመር ከ...
# 2  ሞት በስኳር ለልጆቻችን የምናሲዘው ምሳቃ ሳናቀው እድሚያቸውን ይቀንሰው ይ...
# 3  ከ HIV የተፈወሰ ሰው አጋጥሟችሁ ያቃል ? ፈውስ እና ህክምና ? ሙሉ ቪ...
# 4  በቅርብ ጊዜ በሃገራችን ላይ እየተስተዋለ ያለ የተመሳሳይ ፆታ ( Homos...
#
#                         date                    msg_link  msg_from_peer  \
# 0  2023-12-18 17:04:02+00:00  https://t.me/DoctorsET/864            NaN
# 1  2023-11-03 16:14:39+00:00  https://t.me/DoctorsET/863            NaN
# 2  2023-10-02 16:37:39+00:00  https://t.me/DoctorsET/862            NaN
# 3  2023-09-16 07:54:32+00:00  https://t.me/DoctorsET/861            NaN
# 4  2023-09-01 16:16:15+00:00  https://t.me/DoctorsET/860            NaN
#
#    msg_from_id  ...  contact_name  contact_userid  geo_type  lat lng  \
# 0          NaN  ...           NaN             NaN       NaN  NaN NaN
# 1          NaN  ...           NaN             NaN       NaN  NaN NaN
# 2          NaN  ...           NaN             NaN       NaN  NaN NaN
# 3          NaN  ...           NaN             NaN       NaN  NaN NaN
# 4          NaN  ...           NaN             NaN       NaN  NaN NaN
#
#    venue_id venue_type venue_title venue_address venue_provider
# 0       NaN        NaN         NaN           NaN            NaN
# 1       NaN        NaN         NaN           NaN            NaN
# 2       NaN        NaN         NaN           NaN            NaN
# 3       NaN        NaN         NaN           NaN            NaN
# 4       NaN        NaN         NaN           NaN            NaN
#
# [5 rows x 49 columns]

# %% [markdown]
# #### Data Quality Assessement

# %%
check_missing_data(df_data)
# Out:
#                    Column Name  Missing Values  Percentage Missing
# 4                      message            1171           15.617498
# 5              cleaned_message            1171           15.617498
# 8                msg_from_peer            7498          100.000000
# 9                  msg_from_id            7498          100.000000
# 14  forward_msg_from_peer_type            7150           95.358762
# 15    forward_msg_from_peer_id            7150           95.358762
# 16  forward_msg_from_peer_name            7182           95.785543
# 17            forward_msg_date            7085           94.491864
# 18     forward_msg_date_string            7085           94.491864
# 19            forward_msg_link            7182           95.785543
# 21             reply_to_msg_id            7458           99.466524
# 22              reply_msg_link            7458           99.466524
# 24                  media_type             571            7.615364
# 26                         url            6837           91.184316
# 27                      domain            6837           91.184316
# 28                   url_title            6844           91.277674
# 29             url_description            6855           91.424380
# 30               document_type            7272           96.985863
# 31                 document_id            7272           96.985863
# 32     document_video_duration            7407           98.786343
# 33           document_filename            7357           98.119499
# 34                     poll_id            7492           99.919979
# 35               poll_question            7492           99.919979
# 36           poll_total_voters            7492           99.919979
# 37                poll_results            7492           99.919979
# 38        contact_phone_number            7498          100.000000
# 39                contact_name            7498          100.000000
# 40              contact_userid            7498          100.000000
# 41                    geo_type            7498          100.000000
# 42                         lat            7498          100.000000
# 43                         lng            7498          100.000000
# 44                    venue_id            7498          100.000000
# 45                  venue_type            7498          100.000000
# 46                 venue_title            7498          100.000000
# 47               venue_address            7498          100.000000
# 48              venue_provider            7498          100.000000

# %% [markdown]
# #### Data Cleaning

# %%
def drop_missing_data(df, threshold=90):
    """
    Drop columns from a DataFrame that have missing values over a certain threshold.
    
    Parameters:
    - df: Pandas DataFrame
    - threshold: float, The percentage threshold for missing values. Columns with missing values over this threshold will be dropped.
    
    Returns:
    - DataFrame: DataFrame after dropping the columns
    """
    missing_data = df.isnull().sum()
    missing_data_percentage = (missing_data / len(df)) * 100
    
    # Identify columns to drop
    cols_to_drop = missing_data_percentage[missing_data_percentage > threshold].index
    
    # Drop identified columns
    df_cleaned = df.drop(cols_to_drop, axis=1)
    
    return df_cleaned

df_cleaned = drop_missing_data(df_data, threshold=90)

# %%
df_cleaned.head()
# Out:
#                                  signature  channel_id channel_name  msg_id  \
# 0  msg_iteration.0.user.DoctorsET.post.864  1102021238    DoctorsET     864
# 1  msg_iteration.1.user.DoctorsET.post.863  1102021238    DoctorsET     863
# 2  msg_iteration.2.user.DoctorsET.post.862  1102021238    DoctorsET     862
# 3  msg_iteration.3.user.DoctorsET.post.861  1102021238    DoctorsET     861
# 4  msg_iteration.4.user.DoctorsET.post.860  1102021238    DoctorsET     860
#
#                                              message  \
# 0  https://youtu.be/5DBoEm-8kmA?si=LDLuEecNfULJVD...
# 1  ዶክተርስ ኢትዮጵያ በ አዲስ አቀራረብ በ ቴሌቪዥን ፕሮግራሙን ለመጀመር ከ...
# 2  ሞት በስኳር \n\nለልጆቻችን የምናሲዘው ምሳቃ ሳናቀው እድሚያቸውን ይቀን...
# 3  ከ HIV የተፈወሰ ሰው አጋጥሟችሁ ያቃል ? ፈውስ እና ህክምና ?\n\nሙ...
# 4  በቅርብ ጊዜ በሃገራችን ላይ እየተስተዋለ ያለ የተመሳሳይ ፆታ ( Homos...
#
#                                      cleaned_message  \
# 0  https://youtu.be/5DBoEm-8kmA?si=LDLuEecNfULJVD...
# 1  ዶክተርስ ኢትዮጵያ በ አዲስ አቀራረብ በ ቴሌቪዥን ፕሮግራሙን ለመጀመር ከ...
# 2  ሞት በስኳር ለልጆቻችን የምናሲዘው ምሳቃ ሳናቀው እድሚያቸውን ይቀንሰው ይ...
# 3  ከ HIV የተፈወሰ ሰው አጋጥሟችሁ ያቃል ? ፈውስ እና ህክምና ? ሙሉ ቪ...
# 4  በቅርብ ጊዜ በሃገራችን ላይ እየተስተዋለ ያለ የተመሳሳይ ፆታ ( Homos...
#
#                         date                    msg_link  views  \
# 0  2023-12-18 17:04:02+00:00  https://t.me/DoctorsET/864   5711
# 1  2023-11-03 16:14:39+00:00  https://t.me/DoctorsET/863   8404
# 2  2023-10-02 16:37:39+00:00  https://t.me/DoctorsET/862  10862
# 3  2023-09-16 07:54:32+00:00  https://t.me/DoctorsET/861  11284
# 4  2023-09-01 16:16:15+00:00  https://t.me/DoctorsET/860  13091
#
#    number_replies  number_forwards  is_forward  is_reply  contains_media  \
# 0               0                3           0         0               1
# 1               0                5           0         0               1
# 2               0               56           0         0               1
# 3               0                8           0         0               1
# 4               0               11           0         0               1
#
#             media_type  has_url
# 0  MessageMediaWebPage        1
# 1  MessageMediaWebPage        1
# 2  MessageMediaWebPage        1
# 3  MessageMediaWebPage        1
# 4  MessageMediaWebPage        1

# %%
check_missing_data(df_cleaned)
# Out:
#         Column Name  Missing Values  Percentage Missing
# 4           message            1171           15.617498
# 5   cleaned_message            1171           15.617498
# 14       media_type             571            7.615364

# %%
def remove_duplicates(input_file, output_file):
    # Read the CSV file
    df = pd.read_csv(input_file)
    
    # Drop duplicate rows
    df_cleaned = df.drop_duplicates()
    
    # Write the cleaned DataFrame back to a new CSV file
    df_cleaned.to_csv(output_file, index=False)
    
    print(f"Removed duplicates. Cleaned file saved as '{output_file}'.")

# Usage
input_csv = '../data/msgs_dataset.csv'  # Replace with your input file path
output_csv = '../data/outputs.csv'  # Replace with your desired output file path

remove_duplicates(input_csv, output_csv)
# Out:
# Removed duplicates. Cleaned file saved as '../data/outputs.csv'.

# %%
df_cleaned = pd.read_csv('../data/outputs.csv')

# %%
df_cleaned.head(10)
# Out:
#                                  signature  channel_id channel_name  msg_id  \
# 0  msg_iteration.0.user.DoctorsET.post.864  1102021238    DoctorsET     864
# 1  msg_iteration.1.user.DoctorsET.post.863  1102021238    DoctorsET     863
# 2  msg_iteration.2.user.DoctorsET.post.862  1102021238    DoctorsET     862
# 3  msg_iteration.3.user.DoctorsET.post.861  1102021238    DoctorsET     861
# 4  msg_iteration.4.user.DoctorsET.post.860  1102021238    DoctorsET     860
# 5  msg_iteration.5.user.DoctorsET.post.859  1102021238    DoctorsET     859
# 6  msg_iteration.6.user.DoctorsET.post.848  1102021238    DoctorsET     848
# 7  msg_iteration.7.user.DoctorsET.post.847  1102021238    DoctorsET     847
# 8  msg_iteration.8.user.DoctorsET.post.846  1102021238    DoctorsET     846
# 9  msg_iteration.9.user.DoctorsET.post.845  1102021238    DoctorsET     845
#
#                                              message  \
# 0  https://youtu.be/5DBoEm-8kmA?si=LDLuEecNfULJVD...
# 1  ዶክተርስ ኢትዮጵያ በ አዲስ አቀራረብ በ ቴሌቪዥን ፕሮግራሙን ለመጀመር ከ...
# 2  ሞት በስኳር \n\nለልጆቻችን የምናሲዘው ምሳቃ ሳናቀው እድሚያቸውን ይቀን...
# 3  ከ HIV የተፈወሰ ሰው አጋጥሟችሁ ያቃል ? ፈውስ እና ህክምና ?\n\nሙ...
# 4  በቅርብ ጊዜ በሃገራችን ላይ እየተስተዋለ ያለ የተመሳሳይ ፆታ ( Homos...
# 5  👇👇👇👇👇👇 https://youtu.be/-AR1KO2DbFw?si=47cXLZt...
# 6  ክረምቱን ስፖርት መስራት አስበው ጂም ለመግባት ካልቻሉ ባሉበት ቦታ ሆነው...
# 7  ስፖርት የመስራት ሱስ ይኖር ይሆን?\n\nበአሁኑ ወቅት ብዙ የስፖርት መስ...
# 8  ድንገተኛ አደጋ / የአጥንት ስብራት\n\nአያርገውና ድንገተኛ የሆነ አደጋ...
# 9  ከትንሽ ግዚያት በፊት ስፖርት መስራት እንደ ቅንጦት ይታይ ነበር አሁን ላ...
#
#                                      cleaned_message  \
# 0  https://youtu.be/5DBoEm-8kmA?si=LDLuEecNfULJVD...
# 1  ዶክተርስ ኢትዮጵያ በ አዲስ አቀራረብ በ ቴሌቪዥን ፕሮግራሙን ለመጀመር ከ...
# 2  ሞት በስኳር ለልጆቻችን የምናሲዘው ምሳቃ ሳናቀው እድሚያቸውን ይቀንሰው ይ...
# 3  ከ HIV የተፈወሰ ሰው አጋጥሟችሁ ያቃል ? ፈውስ እና ህክምና ? ሙሉ ቪ...
# 4  በቅርብ ጊዜ በሃገራችን ላይ እየተስተዋለ ያለ የተመሳሳይ ፆታ ( Homos...
# 5  👇👇👇👇👇👇 https://youtu.be/-AR1KO2DbFw?si=47cXLZt...
# 6  ክረምቱን ስፖርት መስራት አስበው ጂም ለመግባት ካልቻሉ ባሉበት ቦታ ሆነው...
# 7  ስፖርት የመስራት ሱስ ይኖር ይሆን? በአሁኑ ወቅት ብዙ የስፖርት መስሪያ ...
# 8  ድንገተኛ አደጋ / የአጥንት ስብራት አያርገውና ድንገተኛ የሆነ አደጋ ቢደ...
# 9  ከትንሽ ግዚያት በፊት ስፖርት መስራት እንደ ቅንጦት ይታይ ነበር አሁን ላ...
#
#                         date                    msg_link  msg_from_peer  \
# 0  2023-12-18 17:04:02+00:00  https://t.me/DoctorsET/864            NaN
# 1  2023-11-03 16:14:39+00:00  https://t.me/DoctorsET/863            NaN
# 2  2023-10-02 16:37:39+00:00  https://t.me/DoctorsET/862            NaN
# 3  2023-09-16 07:54:32+00:00  https://t.me/DoctorsET/861            NaN
# 4  2023-09-01 16:16:15+00:00  https://t.me/DoctorsET/860            NaN
# 5  2023-08-29 17:20:05+00:00  https://t.me/DoctorsET/859            NaN
# 6  2022-08-02 17:42:08+00:00  https://t.me/DoctorsET/848            NaN
# 7  2022-06-12 17:15:47+00:00  https://t.me/DoctorsET/847            NaN
# 8  2022-05-31 17:51:13+00:00  https://t.me/DoctorsET/846            NaN
# 9  2022-05-20 18:04:53+00:00  https://t.me/DoctorsET/845            NaN
#
#    msg_from_id  ...  contact_name  contact_userid  geo_type  lat lng  \
# 0          NaN  ...           NaN             NaN       NaN  NaN NaN
# 1          NaN  ...           NaN             NaN       NaN  NaN NaN
# 2          NaN  ...           NaN             NaN       NaN  NaN NaN
# 3          NaN  ...           NaN             NaN       NaN  NaN NaN
# 4          NaN  ...           NaN             NaN       NaN  NaN NaN
# 5          NaN  ...           NaN             NaN       NaN  NaN NaN
# 6          NaN  ...           NaN             NaN       NaN  NaN NaN
# 7          NaN  ...           NaN             NaN       NaN  NaN NaN
# 8          NaN  ...           NaN             NaN       NaN  NaN NaN
# 9          NaN  ...           NaN             NaN       NaN  NaN NaN
#
#    venue_id venue_type venue_title venue_address venue_provider
# 0       NaN        NaN         NaN           NaN            NaN
# 1       NaN        NaN         NaN           NaN            NaN
# 2       NaN        NaN         NaN           NaN            NaN
# 3       NaN        NaN         NaN           NaN            NaN
# 4       NaN        NaN         NaN           NaN            NaN
# 5       NaN        NaN         NaN           NaN            NaN
# 6       NaN        NaN         NaN           NaN            NaN
# 7       NaN        NaN         NaN           NaN            NaN
# 8       NaN        NaN         NaN           NaN            NaN
# 9       NaN        NaN         NaN           NaN            NaN
#
# [10 rows x 49 columns]

# %%
check_missing_data(df_cleaned)
# Out:
#                    Column Name  Missing Values  Percentage Missing
# 4                      message            1020           15.126798
# 5              cleaned_message            1020           15.126798
# 8                msg_from_peer            6743          100.000000
# 9                  msg_from_id            6743          100.000000
# 14  forward_msg_from_peer_type            6401           94.928074
# 15    forward_msg_from_peer_id            6401           94.928074
# 16  forward_msg_from_peer_name            6432           95.387810
# 17            forward_msg_date            6336           93.964111
# 18     forward_msg_date_string            6336           93.964111
# 19            forward_msg_link            6432           95.387810
# 21             reply_to_msg_id            6703           99.406792
# 22              reply_msg_link            6703           99.406792
# 24                  media_type             425            6.302833
# 26                         url            6239           92.525582
# 27                      domain            6239           92.525582
# 28                   url_title            6245           92.614563
# 29             url_description            6250           92.688714
# 30               document_type            6563           97.330565
# 31                 document_id            6563           97.330565
# 32     document_video_duration            6677           99.021207
# 33           document_filename            6623           98.220377
# 34                     poll_id            6737           99.911019
# 35               poll_question            6737           99.911019
# 36           poll_total_voters            6737           99.911019
# 37                poll_results            6737           99.911019
# 38        contact_phone_number            6743          100.000000
# 39                contact_name            6743          100.000000
# 40              contact_userid            6743          100.000000
# 41                    geo_type            6743          100.000000
# 42                         lat            6743          100.000000
# 43                         lng            6743          100.000000
# 44                    venue_id            6743          100.000000
# 45                  venue_type            6743          100.000000
# 46                 venue_title            6743          100.000000
# 47               venue_address            6743          100.000000
# 48              venue_provider            6743          100.000000

# %%
def drop_missing_data(df, threshold=90):
    """
    Drop columns from a DataFrame that have missing values over a certain threshold.
    
    Parameters:
    - df: Pandas DataFrame
    - threshold: float, The percentage threshold for missing values. Columns with missing values over this threshold will be dropped.
    
    Returns:
    - DataFrame: DataFrame after dropping the columns
    """
    missing_data = df.isnull().sum()
    missing_data_percentage = (missing_data / len(df)) * 100
    
    # Identify columns to drop
    cols_to_drop = missing_data_percentage[missing_data_percentage > threshold].index
    
    # Drop identified columns
    df_cleaned = df.drop(cols_to_drop, axis=1)
    
    return df_cleaned

df_cleaned = drop_missing_data(df_cleaned, threshold=90)

# %%
check_missing_data(df_cleaned)
# Out:
#         Column Name  Missing Values  Percentage Missing
# 4           message            1020           15.126798
# 5   cleaned_message            1020           15.126798
# 14       media_type             425            6.302833

# %%
# Fill specific columns with default values
df_cleaned['message'] = df_cleaned['message'].fillna('No message')
df_cleaned['cleaned_message'] = df_cleaned['cleaned_message'].fillna('No cleaned message')
df_cleaned['media_type'] = df_cleaned['media_type'].fillna('unknown')

# %%
check_missing_data(df_cleaned)
# Out:
# 'Success: No missing values.'

# %% [markdown]
# ##### Data Standardization

# %%
print(df_cleaned.columns)
# Out:
# Index(['signature', 'channel_id', 'channel_name', 'msg_id', 'message',
#        'cleaned_message', 'date', 'msg_link', 'views', 'number_replies',
#        'number_forwards', 'is_forward', 'is_reply', 'contains_media',
#        'media_type', 'has_url'],
#       dtype='object')

# %%
def standardize_formats(df):
    """
    Standardize formats in the DataFrame.
    """
    # Standardize date format
    df['date'] = pd.to_datetime(df['date'], errors='coerce').dt.strftime('%Y-%m-%d %H:%M:%S')

    # Standardize string formatting
    string_columns = [
        'signature', 'channel_name', 'message', 'cleaned_message', 'msg_link',
        'media_type'
    ]
    for col in string_columns:
        df[col] = df[col].str.strip().str.lower()

    # Ensure numerical columns are of correct type
    numerical_columns = [
        'channel_id', 'msg_id', 'views', 'number_replies', 'number_forwards',
        'is_forward', 'is_reply', 'contains_media', 'has_url'
    ]
    for col in numerical_columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')

    return df

def clean_and_standardize_csv(df, output_file):
    # Standardize formats
    df_cleaned = standardize_formats(df)
    
    # Write the cleaned and standardized DataFrame back to a new CSV file
    df_cleaned.to_csv(output_file, index=False)
    
    print(f"standardized file saved as '{output_file}'.")

output_csv = '../data/standardized_outputs.csv'  # Replace with your desired output file path

clean_and_standardize_csv(df_cleaned, output_csv)
# Out:
# Cleaned and standardized file saved as '../data/standardized_outputs.csv'.

# %%
df = pd.read_csv('../data/standardized_outputs.csv')
df.head(3)
# Out:
#                                  signature  channel_id channel_name  msg_id  \
# 0  msg_iteration.0.user.doctorset.post.864  1102021238    doctorset     864
# 1  msg_iteration.1.user.doctorset.post.863  1102021238    doctorset     863
# 2  msg_iteration.2.user.doctorset.post.862  1102021238    doctorset     862
#
#                                              message  \
# 0  https://youtu.be/5dboem-8kma?si=ldlueecnfuljvd...
# 1  ዶክተርስ ኢትዮጵያ በ አዲስ አቀራረብ በ ቴሌቪዥን ፕሮግራሙን ለመጀመር ከ...
# 2  ሞት በስኳር \n\nለልጆቻችን የምናሲዘው ምሳቃ ሳናቀው እድሚያቸውን ይቀን...
#
#                                      cleaned_message                 date  \
# 0  https://youtu.be/5dboem-8kma?si=ldlueecnfuljvd...  2023-12-18 17:04:02
# 1  ዶክተርስ ኢትዮጵያ በ አዲስ አቀራረብ በ ቴሌቪዥን ፕሮግራሙን ለመጀመር ከ...  2023-11-03 16:14:39
# 2  ሞት በስኳር ለልጆቻችን የምናሲዘው ምሳቃ ሳናቀው እድሚያቸውን ይቀንሰው ይ...  2023-10-02 16:37:39
#
#                      msg_link  views  number_replies  number_forwards  \
# 0  https://t.me/doctorset/864   5711               0                3
# 1  https://t.me/doctorset/863   8404               0                5
# 2  https://t.me/doctorset/862  10862               0               56
#
#    is_forward  is_reply  contains_media           media_type  has_url
# 0           0         0               1  messagemediawebpage        1
# 1           0         0               1  messagemediawebpage        1
# 2           0         0               1  messagemediawebpage        1

# %%
def validate_data(df):
    """
    Validate data in the DataFrame.
    """
    # Check for missing values in critical columns
    critical_columns = ['channel_id', 'msg_id', 'date', 'views']
    if df[critical_columns].isnull().any().any():
        raise ValueError("Critical columns contain missing values.")

    # Check that 'views', 'number_replies', and 'number_forwards' are non-negative
    if not (df['views'] >= 0).all():
        raise ValueError("'views' column contains negative values.")
    if not (df['number_replies'] >= 0).all():
        raise ValueError("'number_replies' column contains negative values.")
    if not (df['number_forwards'] >= 0).all():
        raise ValueError("'number_forwards' column contains negative values.")

    # Check that 'is_forward', 'is_reply', 'contains_media', 'has_url' are boolean
    boolean_columns = ['is_forward', 'is_reply', 'contains_media', 'has_url']
    for col in boolean_columns:
        if not df[col].isin([0, 1]).all():
            raise ValueError(f"'{col}' column contains non-boolean values.")

    # Additional validations can be added here as needed

    return True

Is_validated = validate_data(df)
print(Is_validated)
# Out:
# True
